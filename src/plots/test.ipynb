# %%
import matplotlib.pyplot as plt


import numpy as np

A = np.random.rand(100)
B = np.random.rand(100)

# %%
for trj in [A,B]:
    color = 'C0' if trj[0] > 0.5 else 'C1'
    plt.scatter(range(len(trj)), trj, c=color)
plt.show()
