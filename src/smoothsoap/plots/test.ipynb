# %%
import matplotlib.pyplot as plt


import numpy as np

A = np.random.rand(100)
B = np.random.rand(100)

# %%
C = np.zeros((10,3))
D = np.stack([C for i in [1,2]])
D.shape
# Out:
# (2, 10, 3)

# %%
a= [1,3,2]
print(sorted(a))
# Out:
# [1, 2, 3]
